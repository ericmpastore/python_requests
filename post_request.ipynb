# %%
import requests
from pprint import pprint
import webbrowser

# %%
r_post = requests.post('https://www.google.com',data={'search':'Skillsoft'})

# %%
r_post.status_code
# Out:
# 405

# %%
url = r_post.text
webbrowser.open(url)
# Out:
# True
