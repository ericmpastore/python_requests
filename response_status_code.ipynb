# %%
import requests
from pprint import pprint

# %%
ok_resp = requests.get('http://example.com')

# %%
ok_resp.status_code
# Out:
# 200

# %%
ok_resp.ok
# Out:
# True

# %%
bad_resp = requests.get('https://yahoo.com/asdkfsadfyutr')

# %%
bad_resp.status_code
# Out:
# 429

# %%
bad_resp.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 bad_resp.raise_for_status()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.yahoo.com/asdkfsadfyutr

# %%
ok_resp.raise_for_status()

# %%
type(ok_resp.headers)
# Out:
# requests.structures.CaseInsensitiveDict

# %%
pprint(ok_resp.headers)
# Out:
# {'Date': 'Tue, 24 Mar 2026 11:23:44 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Last-Modified': 'Wed, 18 Mar 2026 19:14:43 GMT', 'Allow': 'GET, HEAD', 'Age': '7976', 'cf-cache-status': 'HIT', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '9e154e31cc2d72eb-ORD'}

# %%
ok_resp.headers.get('content-type')
# Out:
# 'text/html'
