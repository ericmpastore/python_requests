# %%
import requests
from pprint import pprint
import json

# %%
r_head = requests.head('http://example.com')

# %%
r_head.status_code
# Out:
# 200

# %%
r_head.text
# Out:
# ''

# %%
pprint(r_head.headers)
# Out:
# {'Date': 'Wed, 18 Mar 2026 16:50:47 GMT', 'Content-Type': 'text/html', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Last-Modified': 'Wed, 18 Mar 2026 04:36:21 GMT', 'Allow': 'GET, HEAD', 'Age': '6671', 'cf-cache-status': 'HIT', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '9de5bd04d871874f-ORD'}
