# %%
import requests
from pprint import pprint

# %%
url = 'http://swapi.co/api/people/3'

# %%
headers = {'user-agent':'Googlechrome'}

# %%
resp = requests.get(url,headers=headers)

# %%
pprint(resp.headers['Date'])
# Out:
# 'Sat, 21 Mar 2026 12:37:08 GMT'

# %%
resp_obj = requests.get('https://en.wikipedia.org/wiki/Monty_Python',headers={'User-Agent': 'MediaWiki REST API docs examples/0.1 (https://www.mediawiki.org/wiki/API_talk:REST_API)'})

# %%
pprint(resp_obj.status_code)
# Out:
# 200

# %%
data = resp_obj.text

# %%
pprint(data[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pprint(data['User-Agent'])
#
# TypeError: string indices must be integers, not 'str'
