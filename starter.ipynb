# %%
# !pip install requests --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2025.1.31)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\epas0\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
from pprint import pprint
import json

# %%
r_get = requests.get('http://universities.hipolabs.com/search?country=United+States')

# %%
r_get.status_code
# Out:
# 200

# %%
r_get.headers
# Out:
# {'Server': 'nginx/1.14.0', 'Date': 'Mon, 09 Mar 2026 10:11:37 GMT', 'Content-Type': 'application/json', 'Content-Length': '437786', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*'}

# %%
type(r_get)
# Out:
# requests.models.Response

# %%
r_get
# Out:
# <Response [200]>

# %%
data = r_get.text

pprint(data)
# Out:
# ('[{"domains": ["marywood.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Marywood University", "web_pages": '
#  '["http://www.marywood.edu"]}, {"domains": ["lindenwood.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lindenwood University", "web_pages": '
#  '["http://www.lindenwood.edu/"]}, {"domains": ["sullivan.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Sullivan University", "web_pages": ["https://sullivan.edu/"]}, '
#  '{"domains": ["fscj.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Florida State College at '
#  'Jacksonville", "web_pages": ["https://www.fscj.edu/"]}, {"domains": '
#  '["xavier.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Xavier University", "web_pages": '
#  '["https://www.xavier.edu/"]}, {"domains": ["tusculum.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Tusculum College", "web_pages": ["https://home.tusculum.edu/"]}, '
#  '{"domains": ["cst.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Claremont School of Theology", "web_pages": '
#  '["https://cst.edu/"]}, {"domains": ["columbiasc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Columbia '
#  'College (SC)", "web_pages": ["https://www.columbiasc.edu/"]}, {"domains": '
#  '["clpccd.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Chabot-Las Positas Community College '
#  'District", "web_pages": ["http://www.clpccd.edu/"]}, {"domains": '
#  '["keller.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Keller Graduate School of Management", '
#  '"web_pages": ["https://www.keller.edu/"]}, {"domains": '
#  '["monroecollege.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Monroe College", "web_pages": '
#  '["https://monroecollege.edu/"]}, {"domains": ["smccd.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "San Mateo County Community College District", "web_pages": '
#  '["https://smccd.edu/"]}, {"domains": ["losrios.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Los Rios '
#  'Community College District", "web_pages": ["http://losrios.edu/"]}, '
#  '{"domains": ["digipen.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "DigiPen Institute of Technology", '
#  '"web_pages": ["https://www.digipen.edu/"]}, {"domains": ["upmc.edu", '
#  '"upmc.com"], "state-province": "Pennsylvania", "country": "United States", '
#  '"alpha_two_code": "US", "name": "University of Pittsburgh Medical Center", '
#  '"web_pages": ["https://www.upmc.com/"]}, {"domains": ["cgu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Claremont Graduate University", "web_pages": '
#  '["https://www.cgu.edu/"]}, {"domains": ["utrgv.edu"], "state-province": '
#  '"Texas", "country": "United States", "alpha_two_code": "US", "name": "The '
#  'University of Texas at Rio Grande Valley", "web_pages": '
#  '["https://www.utrgv.edu/"]}, {"domains": ["mountsaintvincent.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "College of Mount Saint Vincent", "web_pages": '
#  '["https://mountsaintvincent.edu/"]}, {"domains": ["uasys.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "University of Arkansas System eVersity", "web_pages": '
#  '["https://www.uasys.edu/"]}, {"domains": ["ecpi.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "ECPI '
#  'University", "web_pages": ["https://www.ecpi.edu/"]}, {"domains": '
#  '["umw.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "University of Mary Washington", '
#  '"web_pages": ["https://www.umw.edu/"]}, {"domains": ["bw.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Baldwin Wallace University", "web_pages": ["https://www.bw.edu/"]}, '
#  '{"domains": ["csuci.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "California State University '
#  'Channel Islands", "web_pages": ["https://www.csuci.edu/"]}, {"domains": '
#  '["brandman.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Brandman University", "web_pages": '
#  '["https://www.brandman.edu/"]}, {"domains": ["uscga.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "United '
#  'States Coast Guard Academy", "web_pages": ["http://www.uscga.edu/"]}, '
#  '{"domains": ["athens.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Athens State University", '
#  '"web_pages": ["http://www.athens.edu/"]}, {"domains": ["scripps.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "The Scripps Research Institute", "web_pages": '
#  '["https://scripps.edu/"]}, {"domains": ["easternflorida.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Eastern Florida State College", "web_pages": '
#  '["http://www.easternflorida.edu/"]}, {"domains": ["wne.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Western New England University", "web_pages": '
#  '["http://www1.wne.edu/"]}, {"domains": ["king.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "King '
#  'University", "web_pages": ["https://king.edu/"]}, {"domains": ["ggc.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Georgia Gwinnett College", "web_pages": ["https://ggc.edu/"]}, '
#  '{"domains": ["trident.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Trident University", "web_pages": '
#  '["https://www.trident.edu/"]}, {"domains": ["alliant.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Alliant International University", "web_pages": '
#  '["https://www.alliant.edu/"]}, {"domains": ["mvsu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": '
#  '"Mississippi Valley State University", "web_pages": ["https://mvsu.edu/"]}, '
#  '{"domains": ["roosevelt.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Roosevelt University", '
#  '"web_pages": ["https://www.roosevelt.edu/"]}, {"domains": ["itt-tech.info", '
#  '"itt-tech.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "ITT Technical Institute", "web_pages": '
#  '["http://itt-tech.info/"]}, {"domains": ["iecc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Illinois '
#  'Eastern Community Colleges", "web_pages": ["https://iecc.edu/"]}, '
#  '{"domains": ["park.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Park University", "web_pages": '
#  '["https://park.edu/"]}, {"domains": ["mssm.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Icahn School of '
#  'Medicine at Mount Sinai", "web_pages": ["http://icahn.mssm.edu/"]}, '
#  '{"domains": ["uvu.edu"], "state-province": "Utah", "country": "United '
#  'States", "alpha_two_code": "US", "name": "Utah Valley University", '
#  '"web_pages": ["https://uvu.edu/"]}, {"domains": ["wlc.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Wisconsin Lutheran College", "web_pages": ["http://www.wlc.edu/"]}, '
#  '{"domains": ["rccd.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Riverside Community College '
#  'District", "web_pages": ["http://www.rccd.edu/"]}, {"domains": '
#  '["wakehealth.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Wake Forest Baptist Health", "web_pages": '
#  '["http://www.wakehealth.edu/"]}, {"domains": ["umb.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": '
#  '"University of Massachusetts Boston", "web_pages": '
#  '["https://www.umb.edu/"]}, {"domains": ["floridapoly.edu"], '
#  '"state-province": "Florida", "country": "United States", "alpha_two_code": '
#  '"US", "name": "Florida Polytechnic University", "web_pages": '
#  '["https://floridapoly.edu/"]}, {"domains": ["wagner.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Wagner '
#  'College", "web_pages": ["https://wagner.edu/"]}, {"domains": ["wilmu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Wilmington University", "web_pages": ["https://www.wilmu.edu/"]}, '
#  '{"domains": ["itu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "International Technological University", '
#  '"web_pages": ["https://itu.edu/"]}, {"domains": ["yhc.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Young Harris College", "web_pages": ["https://www.yhc.edu/"]}, '
#  '{"domains": ["findlay.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "University of Findlay", '
#  '"web_pages": ["https://www.findlay.edu/"]}, {"domains": ["pcom.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Philadelphia College of Osteopathic Medicine", "web_pages": '
#  '["https://www.pcom.edu/"]}, {"domains": ["yosemite.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Yosemite '
#  'Community College District", "web_pages": ["https://www.yosemite.edu/"]}, '
#  '{"domains": ["coastalalabama.edu"], "state-province": null, "country": '
#  '"United States", "alpha_two_code": "US", "name": "Coastal Alabama Community '
#  'College", "web_pages": ["http://www.coastalalabama.edu/"]}, {"domains": '
#  '["pnw.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Purdue University Northwest", "web_pages": '
#  '["https://www.pnw.edu/"]}, {"domains": ["columbiabasin.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Columbia Basin College", "web_pages": '
#  '["http://www.columbiabasin.edu/"]}, {"domains": ["seattlecolleges.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Seattle Colleges", "web_pages": '
#  '["https://www.seattlecolleges.edu/"]}, {"domains": ["lipscomb.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lipscomb University", "web_pages": ["https://www.lipscomb.edu/"]}, '
#  '{"domains": ["tiffin.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Tiffin University", "web_pages": '
#  '["http://www.tiffin.edu/"]}, {"domains": ["troy.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Troy '
#  'University", "web_pages": ["https://troy.edu/"]}, {"domains": '
#  '["student.42.us.org"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "42 US", "web_pages": '
#  '["http://www.42.us.org/"]}, {"domains": ["calbaptist.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California Baptist University", "web_pages": '
#  '["http://www.calbaptist.edu/"]}, {"domains": ["stevenson.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Stevenson University", "web_pages": ["http://www.stevenson.edu/"]}, '
#  '{"domains": ["mbl.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Marine Biological Laboratory", "web_pages": '
#  '["http://www.mbl.edu/"]}, {"domains": ["maryville.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Maryville '
#  'University", "web_pages": ["http://www.maryville.edu/"]}, {"domains": '
#  '["aii.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "The Art Institutes", "web_pages": '
#  '["http://www.aii.edu/"]}, {"domains": ["umc.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "University of '
#  'Mississippi Medical Center", "web_pages": ["http://www.umc.edu/"]}, '
#  '{"domains": ["uco.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "University of Central Oklahoma", '
#  '"web_pages": ["http://www.uco.edu/"]}, {"domains": '
#  '["hallmarkuniversity.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Hallmark University", "web_pages": '
#  '["http://www.hallmarkuniversity.edu/"]}, {"domains": '
#  '["keiseruniversity.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Keiser University", "web_pages": '
#  '["http://www.keiseruniversity.edu/"]}, {"domains": ["sjrstate.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "St. Johns River State College", "web_pages": '
#  '["http://www.sjrstate.edu/"]}, {"domains": ["irsc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Indian '
#  'River State College", "web_pages": ["http://www.irsc.edu/"]}, {"domains": '
#  '["barnard.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Barnard College", "web_pages": '
#  '["http://www.barnard.edu/"]}, {"domains": ["calsouthern.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California Southern University", "web_pages": '
#  '["http://www.calsouthern.edu/"]}, {"domains": ["laverne.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "University of La Verne", "web_pages": ["http://www.laverne.edu/"]}, '
#  '{"domains": ["washjeff.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Washington & Jefferson College", '
#  '"web_pages": ["http://www.washjeff.edu/"]}, {"domains": ["uopeople.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "University of the People", "web_pages": '
#  '["http://www.uopeople.edu/"]}, {"domains": ["touro.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Touro '
#  'College", "web_pages": ["http://www.touro.edu/"]}, {"domains": ["njcu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "New Jersey City University", "web_pages": '
#  '["http://www.njcu.edu/"]}, {"domains": ["lander.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lander '
#  'University", "web_pages": ["http://www.lander.edu/"]}, {"domains": '
#  '["sunymaritime.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "SUNY Maritime College", "web_pages": '
#  '["http://www.sunymaritime.edu/"]}, {"domains": ["lesley.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lesley University", "web_pages": ["http://www.lesley.edu/"]}, '
#  '{"domains": ["lauruscollege.edu"], "state-province": null, "country": '
#  '"United States", "alpha_two_code": "US", "name": "Laurus College", '
#  '"web_pages": ["http://www.lauruscollege.edu/"]}, {"domains": ["np.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "National Park College", "web_pages": ["http://www.np.edu/"]}, '
#  '{"domains": ["oc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Oklahoma Christian University", '
#  '"web_pages": ["http://www.oc.edu/"]}, {"domains": ["sdcc.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "San Diego Christian College", "web_pages": '
#  '["http://www.sdcc.edu/"]}, {"domains": ["sans.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "SANS Technology '
#  'Institute", "web_pages": ["http://www.sans.edu/"]}, {"domains": '
#  '["phsc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Pasco-Hernando State College", "web_pages": '
#  '["http://www.phsc.edu/"]}, {"domains": ["ncf.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "New College of '
#  'Florida", "web_pages": ["http://www.ncf.edu/"]}, {"domains": ["gcu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Grand Canyon University", "web_pages": ["http://www.gcu.edu/"]}, '
#  '{"domains": ["cshl.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Cold Spring Harbor Laboratory", '
#  '"web_pages": ["http://www.cshl.edu/"]}, {"domains": ["asurams.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Albany State University", "web_pages": '
#  '["http://www.asurams.edu/"]}, {"domains": ["lasell.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lasell '
#  'College", "web_pages": ["http://www.lasell.edu/"]}, {"domains": ["4cd.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Contra Costa Community College District", "web_pages": '
#  '["http://www.4cd.edu/"]}, {"domains": ["msmary.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Mount St. '
#  'Mary\'s University", "web_pages": ["http://www.msmary.edu/"]}, {"domains": '
#  '["robertmorris.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Robert Morris University Illinois", '
#  '"web_pages": ["http://www.robertmorris.edu/"]}, {"domains": ["nwfsc.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Northwest Florida State College", "web_pages": '
#  '["http://www.nwfsc.edu/"]}, {"domains": ["wvwc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "West '
#  'Virginia Wesleyan College", "web_pages": ["http://www.wvwc.edu/"]}, '
#  '{"domains": ["utica.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Utica College", "web_pages": '
#  '["http://www.utica.edu/"]}, {"domains": ["ccnn.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Career '
#  'College of Northern Nevada", "web_pages": ["http://www.ccnn.edu/"]}, '
#  '{"domains": ["csn.edu"], "state-province": "NV", "country": "United States", '
#  '"alpha_two_code": "US", "name": "College of Southern Nevada", "web_pages": '
#  '["https://www.csn.edu/"]}, {"domains": ["ung.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "University of '
#  'North Georgia", "web_pages": ["http://www.ung.edu/"]}, {"domains": '
#  '["principia.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "The Principia", "web_pages": '
#  '["http://www.principia.edu/"]}, {"domains": ["lynn.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lynn '
#  'University", "web_pages": ["http://www.lynn.edu/"]}, {"domains": '
#  '["cccs.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Colorado Community College System", '
#  '"web_pages": ["http://www.cccs.edu/"]}, {"domains": ["valenciacollege.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Valencia College", "web_pages": '
#  '["http://www.valenciacollege.edu/"]}, {"domains": ["spcollege.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "St. Petersburg College", "web_pages": '
#  '["http://www.spcollege.edu/"]}, {"domains": ["msbcollege.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Globe University & Minnesota School of Business", "web_pages": '
#  '["http://www.msbcollege.edu/"]}, {"domains": ["everest.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Everest College", "web_pages": ["http://www.everest.edu/"]}, '
#  '{"domains": ["swri.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Southwest Research Institute", '
#  '"web_pages": ["http://www.swri.edu/"]}, {"domains": ["apus.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "American Public University System", "web_pages": '
#  '["http://www.apus.edu/"]}, {"domains": ["fullsail.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Full Sail '
#  'University", "web_pages": ["http://www.fullsail.edu/"]}, {"domains": '
#  '["yti.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "YTI Career Institute", "web_pages": '
#  '["http://www.yti.edu/"]}, {"domains": ["dliflc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Defense '
#  'Language Institute Foreign Language Center", "web_pages": '
#  '["http://www.dliflc.edu/"]}, {"domains": ["columbusstate.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Columbus State University", "web_pages": '
#  '["http://www.columbusstate.edu/"]}, {"domains": ["moreheadstate.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Morehead State University", "web_pages": '
#  '["http://www.moreheadstate.edu/"]}, {"domains": ["csuglobal.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Colorado State University - Global Campus", "web_pages": '
#  '["http://www.csuglobal.edu/"]}, {"domains": ["ndus.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "North '
#  'Dakota University System", "web_pages": ["http://www.ndus.edu/"]}, '
#  '{"domains": ["uhd.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "University of Houston-Downtown", '
#  '"web_pages": ["http://www.uhd.edu/"]}, {"domains": ["stratford.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Stratford University", "web_pages": ["http://www.stratford.edu/"]}, '
#  '{"domains": ["cpp.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "California Polytechnic State University, '
#  'Pomona", "web_pages": ["http://www.cpp.edu/"]}, {"domains": ["baker.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Baker College", "web_pages": ["http://www.baker.edu/"]}, '
#  '{"domains": ["tcnj.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "The College of New Jersey", '
#  '"web_pages": ["http://www.tcnj.edu/"]}, {"domains": ["acu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Abilene Christian University", "web_pages": '
#  '["http://www.acu.edu/"]}, {"domains": ["adelphi.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Adelphi '
#  'University", "web_pages": ["http://www.adelphi.edu/"]}, {"domains": '
#  '["agnesscott.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Agnes Scott College", "web_pages": '
#  '["http://www.agnesscott.edu/"]}, {"domains": ["atc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Aiken '
#  'Technical College", "web_pages": ["http://www.atc.edu/"]}, {"domains": '
#  '["afit.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Air Force Institute of Technology", '
#  '"web_pages": ["http://www.afit.edu/"]}, {"domains": ["aamu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Alabama A&M University", "web_pages": ["http://www.aamu.edu/"]}, '
#  '{"domains": ["alasu.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Alabama State University", '
#  '"web_pages": ["http://www.alasu.edu/"]}, {"domains": ["aloma.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Alamo Colleges", "web_pages": ["http://www.alamo.edu/"]}, '
#  '{"domains": ["acofi.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Albertson College of Idaho", '
#  '"web_pages": ["http://www.acofi.edu/"]}, {"domains": ["albion.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Albion College", "web_pages": ["http://www.albion.edu/"]}, '
#  '{"domains": ["alfred.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Alfred University", "web_pages": '
#  '["http://www.alfred.edu/"]}, {"domains": ["alleg.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Allegheny '
#  'College", "web_pages": ["http://www.alleg.edu/"]}, {"domains": '
#  '["allencol.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Allentown College of Saint Francis de '
#  'Sales", "web_pages": ["http://www.allencol.edu/"]}, {"domains": '
#  '["alma.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Alma College", "web_pages": '
#  '["http://www.alma.edu/"]}, {"domains": ["alverno.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Alverno '
#  'College", "web_pages": ["http://www.alverno.edu/"]}, {"domains": '
#  '["ambassador.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Ambassador University", "web_pages": '
#  '["http://www.ambassador.edu/"]}, {"domains": ["amercoastuniv.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "American Coastline University", "web_pages": '
#  '["http://www.amercoastuniv.edu/"]}, {"domains": ["aic.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "American International College", "web_pages": '
#  '["http://www.aic.edu/"]}, {"domains": ["american.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "American '
#  'University", "web_pages": ["http://www.american.edu/"]}, {"domains": '
#  '["amherst.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Amherst College", "web_pages": '
#  '["http://www.amherst.edu/"]}, {"domains": ["andrews.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Andrews '
#  'University", "web_pages": ["http://www.andrews.edu/"]}, {"domains": '
#  '["angelo.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Angelo State University", "web_pages": '
#  '["http://www.angelo.edu/"]}, {"domains": ["aacc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Anne '
#  'Arundel Community College", "web_pages": ["http://www.aacc.edu/"]}, '
#  '{"domains": ["antiochne.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Antioch New England", "web_pages": '
#  '["http://www.antiochne.edu/"]}, {"domains": ["antioch.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Antioch University", "web_pages": ["http://www.antioch.edu/"]}, '
#  '{"domains": ["antiochla.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Antioch University - Los Angeles", '
#  '"web_pages": ["http://www.antiochla.edu/"]}, {"domains": '
#  '["seattleantioch.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Antioch University - Seattle", "web_pages": '
#  '["http://www.seattleantioch.edu/"]}, {"domains": ["appstate.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Appalachian State University", "web_pages": '
#  '["http://www.appstate.edu/"]}, {"domains": ["aquinas.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Aquinas College", "web_pages": ["http://www.aquinas.edu/"]}, '
#  '{"domains": ["arcadia.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Arcadia College", "web_pages": '
#  '["http://www.arcadia.edu/"]}, {"domains": ["asu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Arizona '
#  'State University", "web_pages": ["http://www.asu.edu/"]}, {"domains": '
#  '["azwestern.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Arizona Western College", "web_pages": '
#  '["http://www.azwestern.edu/"]}, {"domains": ["astate.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Arkansas State University", "web_pages": '
#  '["http://www.astate.edu/"]}, {"domains": ["atu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Arkansas '
#  'Tech University", "web_pages": ["http://www.atu.edu/"]}, {"domains": '
#  '["armstrong.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Armstrong State College", "web_pages": '
#  '["http://www.armstrong.edu/"]}, {"domains": ["ashland.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Ashland University", "web_pages": ["http://www.ashland.edu/"]}, '
#  '{"domains": ["assumption.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Assumption College", "web_pages": '
#  '["http://www.assumption.edu/"]}, {"domains": ["auburn.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Auburn University", "web_pages": ["http://www.auburn.edu/"]}, '
#  '{"domains": ["aum.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Auburn University at Montgomery", '
#  '"web_pages": ["http://www.aum.edu/"]}, {"domains": ["augsburg.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Augsburg College", "web_pages": ["http://www.augsburg.edu/"]}, '
#  '{"domains": ["augustana.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Augustana College (IL)", '
#  '"web_pages": ["http://www.augustana.edu/"]}, {"domains": ["augie.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Augustana College (SD)", "web_pages": ["http://www.augie.edu/"]}, '
#  '{"domains": ["augusta.edu", "gru.edu"], "state-province": null, "country": '
#  '"United States", "alpha_two_code": "US", "name": "Augusta University", '
#  '"web_pages": ["http://www.augusta.edu/", "http://www.gru.edu/"]}, '
#  '{"domains": ["aurora.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Aurora University", "web_pages": '
#  '["http://www.aurora.edu/"]}, {"domains": ["austincollege.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Austin College", "web_pages": ["http://www.austincollege.edu/"]}, '
#  '{"domains": ["austincc.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Austin Community College", '
#  '"web_pages": ["http://www.austincc.edu/"]}, {"domains": ["apsu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Austin Peay State University", "web_pages": '
#  '["http://www.apsu.edu/"]}, {"domains": ["averett.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Averett '
#  'College", "web_pages": ["http://www.averett.edu/"]}, {"domains": '
#  '["avila.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Avila College", "web_pages": '
#  '["http://www.avila.edu/"]}, {"domains": ["apu.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Azusa Pacific '
#  'University", "web_pages": ["http://www.apu.edu/"]}, {"domains": '
#  '["babson.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Babson College", "web_pages": '
#  '["http://www.babson.edu/"]}, {"domains": ["bakeru.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Baker '
#  'University", "web_pages": ["http://www.bakeru.edu/"]}, {"domains": '
#  '["bsu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Ball State University", "web_pages": '
#  '["http://www.bsu.edu/"]}, {"domains": ["bbc.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Baptist Bible '
#  'College", "web_pages": ["http://www.bbc.edu/"]}, {"domains": ["bard.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Bard College", "web_pages": ["http://www.bard.edu/"]}, {"domains": '
#  '["barry.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Barry University", "web_pages": '
#  '["http://www.barry.edu/"]}, {"domains": ["bastyr.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Bastyr '
#  'University", "web_pages": ["http://www.bastyr.edu/"]}, {"domains": '
#  '["bates.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Bates College", "web_pages": '
#  '["http://www.bates.edu/"]}, {"domains": ["bcm.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Baylor College '
#  'of Medicine", "web_pages": ["http://www.bcm.edu/"]}, {"domains": '
#  '["baylor.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Baylor University", "web_pages": '
#  '["http://www.baylor.edu/"]}, {"domains": ["bellevue.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Bellevue '
#  'University", "web_pages": ["http://www.bellevue.edu/"]}, {"domains": '
#  '["belmont.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Belmont University", "web_pages": '
#  '["http://www.belmont.edu/"]}, {"domains": ["beloit.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Beloit '
#  'College", "web_pages": ["http://www.beloit.edu/"]}, {"domains": '
#  '["bemidjistate.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Bemidji State University", "web_pages": '
#  '["http://www.bemidjistate.edu/"]}, {"domains": ["benedictine.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Benedictine College", "web_pages": '
#  '["http://www.benedictine.edu/"]}, {"domains": ["bennington.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Bennington College", "web_pages": ["http://www.bennington.edu/"]}, '
#  '{"domains": ["bentley.edu"], "state-province": "Massachusetts", "country": '
#  '"United States", "alpha_two_code": "US", "name": "Bentley University", '
#  '"web_pages": ["http://www.bentley.edu/"]}, {"domains": ["berea.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Berea College", "web_pages": ["http://www.berea.edu/"]}, '
#  '{"domains": ["berklee.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Berklee College of Music", '
#  '"web_pages": ["http://www.berklee.edu/"]}, {"domains": ["bethanywv.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Bethany College", "web_pages": ["http://www.bethanywv.edu/"]}, '
#  '{"domains": ["bethelks.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Bethel College (KS)", "web_pages": '
#  '["http://www.bethelks.edu/"]}, {"domains": ["bethel.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Bethel '
#  'University", "web_pages": ["http://www.bethel.edu/"]}, {"domains": '
#  '["biola.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Biola University", "web_pages": '
#  '["http://www.biola.edu/"]}, {"domains": ["bsc.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": '
#  '"Birmingham-Southern College", "web_pages": ["http://www.bsc.edu/"]}, '
#  '{"domains": ["bhsu.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Black Hills State University", '
#  '"web_pages": ["http://www.bhsu.edu/"]}, {"domains": ["bloomu.edu"], '
#  '"state-province": "Pennsylvania", "country": "United States", '
#  '"alpha_two_code": "US", "name": "Bloomsburg University of Pennsylvania", '
#  '"web_pages": ["http://www.bloomu.edu/"]}, {"domains": ["bluffton.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Bluffton College", "web_pages": ["http://www.bluffton.edu/"]}, '
#  '{"domains": ["bju.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Bob Jones University", "web_pages": '
#  '["http://www.bju.edu/"]}, {"domains": ["boisestate.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Boise '
#  'State University", "web_pages": ["http://www.boisestate.edu/"]}, {"domains": '
#  '["bc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Boston College", "web_pages": '
#  '["http://www.bc.edu/"]}, {"domains": ["bgsp.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Boston Graduate '
#  'School of Psychoanalysis", "web_pages": ["http://www.bgsp.edu/"]}, '
#  '{"domains": ["bu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Boston University", "web_pages": '
#  '["http://www.bu.edu/"]}, {"domains": ["bowdoin.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Bowdoin '
#  'College", "web_pages": ["http://www.bowdoin.edu/"]}, {"domains": '
#  '["bowiestate.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Bowie State University", "web_pages": '
#  '["http://www.bowiestate.edu/"]}, {"domains": ["bgsu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Bowling '
#  'Green State University", "web_pages": ["http://www.bgsu.edu/"]}, {"domains": '
#  '["bradley.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Bradley University", "web_pages": '
#  '["http://www.bradley.edu/"]}, {"domains": ["brandeis.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Brandeis University", "web_pages": ["http://www.brandeis.edu/"]}, '
#  '{"domains": ["brenau.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Brenau University", "web_pages": '
#  '["http://www.brenau.edu/"]}, {"domains": ["briar-cliff.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Briar Cliff College", "web_pages": '
#  '["http://www.briar-cliff.edu/"]}, {"domains": ["bridgewater.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Bridgewater College", "web_pages": '
#  '["http://www.bridgewater.edu/"]}, {"domains": ["byu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Brigham '
#  'Young University", "web_pages": ["http://www.byu.edu/"]}, {"domains": '
#  '["byui.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Brigham Young University - Idaho", '
#  '"web_pages": ["http://www.byui.edu/"]}, {"domains": ["byuh.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Brigham Young University Hawaii", "web_pages": '
#  '["http://www.byuh.edu/"]}, {"domains": ["broward.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Broward '
#  'College", "web_pages": ["http://www.broward.edu/"]}, {"domains": '
#  '["brown.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Brown University", "web_pages": '
#  '["http://www.brown.edu/"]}, {"domains": ["bryant.edu"], "state-province": '
#  '"Rhode Island", "country": "United States", "alpha_two_code": "US", "name": '
#  '"Bryant University", "web_pages": ["http://www.bryant.edu/"]}, {"domains": '
#  '["brynmawr.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Bryn Mawr College", "web_pages": '
#  '["http://www.brynmawr.edu/college"]}, {"domains": ["bucknell.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Bucknell University", "web_pages": ["http://www.bucknell.edu/"]}, '
#  '{"domains": ["bvu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Buena Vista University", "web_pages": '
#  '["http://www.bvu.edu/"]}, {"domains": ["butler.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Butler '
#  'University", "web_pages": ["http://www.butler.edu/"]}, {"domains": '
#  '["calcoast.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "California Coast University", "web_pages": '
#  '["http://www.calcoast.edu/"]}, {"domains": ["caltech.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California Institute of Technology", "web_pages": '
#  '["http://www.caltech.edu/"]}, {"domains": ["callutheran.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California Lutheran University", "web_pages": '
#  '["http://www.callutheran.edu/"]}, {"domains": ["csum.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California Maritime Academy", "web_pages": '
#  '["http://www.csum.edu/"]}, {"domains": ["cnuas.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": '
#  '"California National University", "web_pages": ["http://www.cnuas.edu/"]}, '
#  '{"domains": ["calpoly.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "California Polytechnic State '
#  'University, San Luis Obispo", "web_pages": ["http://www.calpoly.edu/"]}, '
#  '{"domains": ["csub.edu", "csubak.edu"], "state-province": null, "country": '
#  '"United States", "alpha_two_code": "US", "name": "California State '
#  'University, Bakersfield", "web_pages": ["http://www.csub.edu/"]}, '
#  '{"domains": ["csuchico.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "California State University, '
#  'Chico", "web_pages": ["http://www.csuchico.edu/"]}, {"domains": '
#  '["csudh.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "California State University, Dominguez '
#  'Hills", "web_pages": ["http://www.csudh.edu/"]}, {"domains": '
#  '["csufresno.edu", "fresnostate.edu"], "state-province": null, "country": '
#  '"United States", "alpha_two_code": "US", "name": "California State '
#  'University, Fresno", "web_pages": ["http://www.csufresno.edu/", '
#  '"http://www.fresnostate.edu/"]}, {"domains": ["fullerton.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California State University, Fullerton", "web_pages": '
#  '["http://www.fullerton.edu/"]}, {"domains": ["csuhayward.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California State University, Hayward", "web_pages": '
#  '["http://www.csuhayward.edu/"]}, {"domains": ["csulb.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California State University, Long Beach", "web_pages": '
#  '["http://www.csulb.edu/"]}, {"domains": ["calstatela.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California State University, Los Angeles", "web_pages": '
#  '["http://www.calstatela.edu/"]}, {"domains": ["csumb.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California State University, Monterey Bay", "web_pages": '
#  '["http://www.csumb.edu/"]}, {"domains": ["csun.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": '
#  '"California State University, Northridge", "web_pages": '
#  '["http://www.csun.edu/"]}, {"domains": ["csus.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "California '
#  'State University, Sacramento", "web_pages": ["http://www.csus.edu/"]}, '
#  '{"domains": ["csusb.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "California State University, San '
#  'Bernardino", "web_pages": ["http://www.csusb.edu/"]}, {"domains": '
#  '["csusm.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "California State University, San Marcos", '
#  '"web_pages": ["http://www.csusm.edu/"]}, {"domains": ["csustan.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California State University, Stanislaus", "web_pages": '
#  '["http://www.csustan.edu/"]}, {"domains": ["calstate.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "California State University System", "web_pages": '
#  '["http://www.calstate.edu/"]}, {"domains": ["cup.edu"], "state-province": '
#  '"Pennsylvania", "country": "United States", "alpha_two_code": "US", "name": '
#  '"California University of Pennsylvania", "web_pages": '
#  '["http://www.cup.edu/"]}, {"domains": ["calvin.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Calvin '
#  'College", "web_pages": ["http://www.calvin.edu/"]}, {"domains": '
#  '["cameron.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Cameron University", "web_pages": '
# ...
#  '["http://www.iusb.edu/"]}, {"domains": ["iup.edu"], "state-province": '
#  '"Pennsylvania", "country": "United States", "alpha_two_code": "US", "name": '
#  '"Indiana University of Pennsylvania", "web_pages": ["http://www.iup.edu/"]}, '
#  '{"domains": ["iupuc.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Indiana University/Purdue '
#  'University at Columbus", "web_pages": ["http://www.iupuc.edu/"]}, '
#  '{"domains": ["ipfw.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Indiana University/Purdue '
#  'University at Fort Wayne", "web_pages": ["http://www.ipfw.edu/"]}, '
#  '{"domains": ["iupui.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Indiana University/Purdue '
#  'University at Indianapolis", "web_pages": ["http://www.iupui.edu/"]}, '
#  '{"domains": ["ius.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Indiana University Southeast", "web_pages": '
#  '["http://www.ius.edu/"]}, {"domains": ["indwes.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Indiana '
#  'Wesleyan University, Marion", "web_pages": ["http://www.indwes.edu/"]}, '
#  '{"domains": ["ias.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Institute for Advanced Study", "web_pages": '
#  '["http://www.ias.edu/"]}, {"domains": ["iwp.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Institute for '
#  'World Politics", "web_pages": ["http://www.iwp.edu/"]}, {"domains": '
#  '["iona.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Iona College", "web_pages": '
#  '["http://www.iona.edu/"]}, {"domains": ["iastate.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Iowa '
#  'State University", "web_pages": ["http://www.iastate.edu/"]}, {"domains": '
#  '["ivc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Irvine Valley College", "web_pages": '
#  '["http://www.ivc.edu/"]}, {"domains": ["ithaca.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Ithaca '
#  'College", "web_pages": ["http://www.ithaca.edu/"]}, {"domains": '
#  '["jsums.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Jackson State University", "web_pages": '
#  '["http://www.jsums.edu/"]}, {"domains": ["jsu.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Jacksonville '
#  'State University", "web_pages": ["http://www.jsu.edu/"]}, {"domains": '
#  '["ju.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Jacksonville University", "web_pages": '
#  '["http://www.ju.edu/"]}, {"domains": ["jmu.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "James Madison '
#  'University", "web_pages": ["http://www.jmu.edu/"]}, {"domains": ["jbu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "John Brown University", "web_pages": ["http://www.jbu.edu/"]}, '
#  '{"domains": ["jfku.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "John F. Kennedy University", '
#  '"web_pages": ["http://www.jfku.edu/"]}, {"domains": ["jh.edu", "jhu.edu", '
#  '"johnshopkins.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Johns Hopkins University", "web_pages": '
#  '["http://www.jhu.edu/"]}, {"domains": ["jhuapl.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Johns '
#  'Hopkins University Applied Physics Laboratory", "web_pages": '
#  '["http://www.jhuapl.edu/"]}, {"domains": ["jwu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Johnson & '
#  'Wales University", "web_pages": ["http://www.jwu.edu/"]}, {"domains": '
#  '["jbc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Johnson Bible College", "web_pages": '
#  '["http://www.jbc.edu/"]}, {"domains": ["jcsu.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Johnson C. '
#  'Smith University", "web_pages": ["http://www.jcsu.edu/"]}, {"domains": '
#  '["jones.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Jones College", "web_pages": '
#  '["http://www.jones.edu/"]}, {"domains": ["judson.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Judson '
#  'College", "web_pages": ["http://www.judson.edu/"]}, {"domains": '
#  '["juniata.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Juniata College", "web_pages": '
#  '["http://www.juniata.edu/"]}, {"domains": ["kzoo.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Kalamazoo '
#  'College", "web_pages": ["http://www.kzoo.edu/"]}, {"domains": ["ksu.edu", '
#  '"k-state.edu"], "state-province": "Kansas", "country": "United States", '
#  '"alpha_two_code": "US", "name": "Kansas State University", "web_pages": '
#  '["https://www.k-state.edu/"]}, {"domains": ["kwu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Kansas '
#  'Wesleyan University", "web_pages": ["http://www.kwu.edu/"]}, {"domains": '
#  '["kaplan.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Kaplan University", "web_pages": '
#  '["http://www.kaplan.edu/"]}, {"domains": ["kean.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Kean '
#  'College", "web_pages": ["http://www.kean.edu/"]}, {"domains": ["keene.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Keene State College", "web_pages": ["http://www.keene.edu/"]}, '
#  '{"domains": ["kennesaw.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Kennesaw State University", '
#  '"web_pages": ["http://www.kennesaw.edu/"]}, {"domains": ["kent.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Kent State University", "web_pages": ["http://www.kent.edu/"]}, '
#  '{"domains": ["kctcs.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Kentucky Community & Technical '
#  'College System", "web_pages": ["http://www.kctcs.edu/"]}, {"domains": '
#  '["kenyon.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Kenyon College", "web_pages": '
#  '["http://www.kenyon.edu/"]}, {"domains": ["kettering.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Kettering University", "web_pages": ["http://www.kettering.edu/"]}, '
#  '{"domains": ["kings.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "King\'s College", "web_pages": '
#  '["http://www.kings.edu/"]}, {"domains": ["knox.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Knox '
#  'College", "web_pages": ["http://www.knox.edu/"]}, {"domains": '
#  '["kutztown.edu"], "state-province": "Pennsylvania", "country": "United '
#  'States", "alpha_two_code": "US", "name": "Kutztown University of '
#  'Pennsylvania", "web_pages": ["http://www.kutztown.edu/"]}, {"domains": '
#  '["lafayette.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Lafayette College", "web_pages": '
#  '["http://www.lafayette.edu/"]}, {"domains": ["lagrange.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "LaGrange College", "web_pages": ["http://www.lagrange.edu/"]}, '
#  '{"domains": ["lfc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Lake Forest College", "web_pages": '
#  '["http://www.lfc.edu/"]}, {"domains": ["lsc.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Lake Superior '
#  'College", "web_pages": ["http://www.lsc.edu/"]}, {"domains": ["lssu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lake Superior State University", "web_pages": '
#  '["http://www.lssu.edu/"]}, {"domains": ["lamar.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lamar '
#  'University", "web_pages": ["http://www.lamar.edu/"]}, {"domains": '
#  '["langston.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Langston University", "web_pages": '
#  '["http://www.langston.edu/"]}, {"domains": ["lasalle.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "LaSalle University", "web_pages": ["http://www.lasalle.edu/"]}, '
#  '{"domains": ["lasierra.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "La Sierra University", '
#  '"web_pages": ["http://www.lasierra.edu/"]}, {"domains": ["ltu.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lawrence Technological University", "web_pages": '
#  '["http://www.ltu.edu/"]}, {"domains": ["lawrence.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lawrence '
#  'University", "web_pages": ["http://www.lawrence.edu/"]}, {"domains": '
#  '["lvc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Lebanon Valley College", "web_pages": '
#  '["http://www.lvc.edu/"]}, {"domains": ["lehigh.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lehigh '
#  'University", "web_pages": ["http://www.lehigh.edu/"]}, {"domains": '
#  '["lemoyne.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Le Moyne College", "web_pages": '
#  '["http://www.lemoyne.edu/"]}, {"domains": ["lenoircc.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lenoir Community College", "web_pages": '
#  '["http://www.lenoircc.edu/"]}, {"domains": ["lrc.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": '
#  '"Lenoir-Rhyne College", "web_pages": ["http://www.lrc.edu/"]}, {"domains": '
#  '["letu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "LeTourneau University", "web_pages": '
#  '["http://www.letu.edu/"]}, {"domains": ["lclark.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lewis & '
#  'Clark College", "web_pages": ["http://www.lclark.edu/"]}, {"domains": '
#  '["lcsc.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Lewis-Clark State College", "web_pages": '
#  '["http://www.lcsc.edu/"]}, {"domains": ["lewisu.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lewis '
#  'University", "web_pages": ["http://www.lewisu.edu/"]}, {"domains": '
#  '["liberty.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Liberty University", "web_pages": '
#  '["http://www.liberty.edu/"]}, {"domains": ["lincoln.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Lincoln '
#  'University", "web_pages": ["http://www.lincoln.edu/"]}, {"domains": '
#  '["linfield.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Linfield College", "web_pages": '
#  '["http://www.linfield.edu/"]}, {"domains": ["lhup.edu", "lockhaven.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lock Haven University", "web_pages": ["https://lockhaven.edu/"]}, '
#  '{"domains": ["llu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Loma Linda University", "web_pages": '
#  '["http://www.llu.edu/"]}, {"domains": ["liunet.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Long '
#  'Island University", "web_pages": ["http://www.liu.edu/"]}, {"domains": '
#  '["longwood.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Longwood University", "web_pages": '
#  '["http://www.longwood.edu/"]}, {"domains": ["loras.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "US", "name": "Loras '
#  'College", "web_pages": ["http://www.loras.edu/"]}, {"domains": '
#  '["laccd.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Los Angeles Community College District", '
#  '"web_pages": ["http://www.laccd.edu/"]}, {"domains": ["lacollege.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Louisiana College", "web_pages": ["http://www.lacollege.edu/"]}, '
#  '{"domains": ["lsu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Louisiana State University", "web_pages": '
#  '["http://www.lsu.edu/"]}, {"domains": ["lsua.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Louisiana State '
#  'University at Alexandria", "web_pages": ["http://www.lsua.edu/"]}, '
#  '{"domains": ["latech.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Louisiana Tech University", '
#  '"web_pages": ["http://www.latech.edu/"]}, {"domains": ["loyola.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Loyola College", "web_pages": ["http://www.loyola.edu/"]}, '
#  '{"domains": ["lmu.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Loyola Marymount University", "web_pages": '
#  '["http://www.lmu.edu/"]}, {"domains": ["luc.edu"], "state-province": null, '
#  '"country": "United States", "alpha_two_code": "US", "name": "Loyola '
#  'University Chicago", "web_pages": ["http://www.luc.edu/"]}, {"domains": '
#  '["luther.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Luther College", "web_pages": '
#  '["http://www.luther.edu/"]}, {"domains": ["luthersem.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Luther Seminary", "web_pages": ["http://www.luthersem.edu/"]}, '
#  '{"domains": ["lycoming.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Lycoming College", "web_pages": '
#  '["http://www.lycoming.edu/"]}, {"domains": ["lynchburg.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lynchburg College", "web_pages": ["http://www.lynchburg.edu/"]}, '
#  '{"domains": ["lyndonstate.edu"], "state-province": null, "country": "United '
#  'States", "alpha_two_code": "US", "name": "Lyndon State College", '
#  '"web_pages": ["http://www.lyndonstate.edu/"]}, {"domains": ["lyon.edu"], '
#  '"state-province": null, "country": "United States", "alpha_two_code": "US", '
#  '"name": "Lyon College", "web_pages": ["http://www.lyon.edu/"]}, {"domains": '
#  '["macalester.edu"], "state-province": null, "country": "United States", '
#  '"alpha_two_code": "US", "name": "Macalester College", "web_pages": '
#  '["http://www.macalester.edu/"]}, {"domains": ["mum.edu"], "state-province": '
#  'null, "country": "United States", "alpha_two_code": "U')

# %%
len(data)
# Out:
# 104930

# %%
r_get = requests.get("https://swapi.dev/api/starships/9/")
# r_get.status_code
r_get.headers
# Out:
# {'Server': 'nginx/1.16.1', 'Date': 'Mon, 09 Mar 2026 10:25:23 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept, Cookie', 'X-Frame-Options': 'SAMEORIGIN', 'ETag': '"058c95fce38484128f1c3f2e5dd04d50"', 'Allow': 'GET, HEAD, OPTIONS', 'Strict-Transport-Security': 'max-age=15768000'}
