# %%
# !pip install requests --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.32.3)
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\epas0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2025.1.31)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Installing collected packages: requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# Successfully installed requests-2.32.5
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\epas0\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
from pprint import pprint
import json

# %%
r_get = requests.get('http://universities.hipolabs.com/search?country=United+States')

# %%
r_get.status_code
# Out:
# 200

# %%
r_get.headers
# Out:
# {'Server': 'nginx/1.14.0', 'Date': 'Fri, 06 Mar 2026 14:39:30 GMT', 'Content-Type': 'application/json', 'Content-Length': '437786', 'Connection': 'keep-alive', 'Access-Control-Allow-Origin': '*'}

# %%
type(r_get)
# Out:
# requests.models.Response

# %%
r_get
# Out:
# <Response [200]>
